# %%
# 5
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = yf.download(
    "AAPL",
    start="2023-01-01",
    end="2025-01-01"
)

df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  122.876747  128.604505  121.992528  127.995383  112117500
# 2023-01-04  124.144112  126.403781  122.886559  124.664816   89113600
# 2023-01-05  122.827621  125.529397  122.572186  124.900621   80962700
# 2023-01-06  127.346939  128.005188  122.699890  123.800252   87754700
# 2023-01-09  127.867653  131.070494  127.612218  128.182048   70790800

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 502 entries, 2023-01-03 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   502 non-null    float64
#  1   (High, AAPL)    502 non-null    float64
#  2   (Low, AAPL)     502 non-null    float64
#  3   (Open, AAPL)    502 non-null    float64
#  4   (Volume, AAPL)  502 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 23.5 KB

# %%
df.describe()
# Out:
# Price        Close        High         Low        Open        Volume
# Ticker        AAPL        AAPL        AAPL        AAPL          AAPL
# count   502.000000  502.000000  502.000000  502.000000  5.020000e+02
# mean    187.734336  189.223931  185.975969  187.464783  5.816095e+07
# std      28.037885   28.178818   27.797285   28.032338  2.512372e+07
# min     122.827621  125.529397  121.992528  123.800252  2.323470e+07
# 25%     169.639366  171.257650  168.392942  169.716677  4.495800e+07
# 50%     182.977280  184.313909  181.363880  182.920914  5.250285e+07
# 75%     212.254219  215.008741  209.956104  212.474620  6.489808e+07
# max     257.153809  258.226044  255.773839  256.329802  3.186799e+08

# %%
plt.figure(figsize=(12, 6))

plt.plot(df.index, df["Close"])

plt.title("Apple Stock Closing Price")
plt.xlabel("Date")
plt.ylabel("Price")

plt.show()

# %%
df["MA_20"] = df["Close"].rolling(window=20).mean()

df.head()
# Out:
# Price            Close        High         Low        Open     Volume MA_20
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  122.876747  128.604505  121.992528  127.995383  112117500   NaN
# 2023-01-04  124.144112  126.403781  122.886559  124.664816   89113600   NaN
# 2023-01-05  122.827621  125.529397  122.572186  124.900621   80962700   NaN
# 2023-01-06  127.346939  128.005188  122.699890  123.800252   87754700   NaN
# 2023-01-09  127.867653  131.070494  127.612218  128.182048   70790800   NaN

# %%
plt.figure(figsize=(12, 6))

plt.plot(df.index, df["Close"], label="Closing Price")
plt.plot(df.index, df["MA_20"], label="20 Day Moving Average")

plt.title("Stock Price and Moving Average")

plt.xlabel("Date")
plt.ylabel("Price")

plt.legend()

plt.show()

# %%
df = pd.read_csv("air_quality.csv")

plt.figure(figsize=(12, 6))

plt.bar(df.index, df["AQI"])

plt.title("Stock Trading Volume")

plt.xlabel("Date")
plt.ylabel("AQI")

plt.show()
